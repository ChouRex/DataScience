# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics
import seaborn as sns

# %% [markdown]
# ### 資料處理
# 1. 取出目標欄位
# 2. 將離散值轉成連續值

# %%
df_train = pd.read_csv("Titanic_train.csv")

# %%
data = df_train[["Pclass", "Sex", "Age"]]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
data["Sex"] = le.fit_transform(data["Sex"])
# Out:
# <ipython-input-26-a36b4f7447f8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Sex"] = le.fit_transform(data["Sex"])

# %%
g = sns.catplot("Sex", "Age", data = data, kind = "box", height = 5, aspect = .8) # 男女都有小孩族群

# %%
g = sns.catplot("Pclass", "Age", data = data, kind = "box", height = 5, aspect = .8) # 男女都有小孩族群

# %%
from sklearn.metrics.pairwise import nan_euclidean_distances
pd.DataFrame(nan_euclidean_distances(data))
# Out:
#            0          1          2          3          4         5    \
# 0     0.000000  16.155494   4.123106  13.190906  13.000000  0.000000
# 1    16.155494   0.000000  12.165525   3.000000   3.741657  2.738613
# 2     4.123106  12.165525   0.000000   9.219544   9.055385  1.224745
# 3    13.190906   3.000000   9.219544   0.000000   2.236068  2.738613
# 4    13.000000   3.741657   9.055385   2.236068   0.000000  0.000000
# ..         ...        ...        ...        ...        ...       ...
# 886   5.099020  11.090537   1.732051   8.124038   8.062258  1.224745
# 887   3.741657  19.000000   7.280110  16.000000  16.155494  2.738613
# 888   1.224745   2.449490   0.000000   2.449490   1.224745  1.224745
# 889   4.472136  12.041595   2.236068   9.055385   9.219544  2.449490
# 890  10.000000   6.403124   6.082763   3.741657   3.000000  0.000000
#
#            6          7          8          9    ...        881        882  \
# ...

# %%
value_neighbors = 3
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors = value_neighbors, add_indicator = True)
data = pd.DataFrame(imputer.fit_transform(data))
data.rename(columns = {0 : "Pclass", 1 : "Sexcode", 2 : "Age", 3 : "imputed_age"}, inplace = True)
data[data["imputed_age"] == 1.0]
# Out:
#      Pclass  Sexcode        Age  imputed_age
# 5       3.0      1.0  19.666667          1.0
# 17      2.0      1.0  45.000000          1.0
# 19      3.0      0.0  19.000000          1.0
# 26      3.0      1.0  19.666667          1.0
# 28      3.0      0.0  19.000000          1.0
# ..      ...      ...        ...          ...
# 859     3.0      1.0  19.666667          1.0
# 863     3.0      0.0  19.000000          1.0
# 868     3.0      1.0  19.666667          1.0
# 878     3.0      1.0  19.666667          1.0
# 888     3.0      0.0  19.000000          1.0
#
# [177 rows x 4 columns]
